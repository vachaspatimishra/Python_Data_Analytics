# %%
print("I love python")
# Out:
# I love python

# %%
print("India is beautiful")
# Out:
# India is beautiful

# %%
a = 1
b = 0.5
c = True
d = "vp"

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# bool

# %%
type(d)
# Out:
# str

# %%
a = 2
b = 3
print("Addition of two numbers is", a+b)
# Out:
# Addition of two numbers is 5

# %%
a = 5
b = 3
print("Subtraction of two numbers is", a-b)
# Out:
# Subtraction of two numbers is 2

# %%
x = 5
y = 2
print("Multiplication of x and y is", x*y)
# Out:
# Multiplication of x and y is 10

# %%
p = 10
q = 2
print("Division of p and q is", p/q)
# Out:
# Division of p and q is 5.0

# %%
a = int(input("Enter first number :" ))
b = int(input("Enter second number :"))
print("Addition of two numbers is :", a+b)
# Out:
# Enter first number :50
# Enter second number :20
# Addition of two numbers is : 70

# %%
a = int(input("Enter first number :" ))
b = int(input("Enter second number :"))
print("Subtraction of two numbers is :", a-b)
# Out:
# Enter first number :50
# Enter second number :30
# Subtraction of two numbers is : 20

# %%
a = int(input("Enter first number :" ))
b = int(input("Enter second number :"))
print("Multiplication of two numbers is :", a*b)
# Out:
# Enter first number :50
# Enter second number :2
# Multiplication of two numbers is : 100

# %%
a = int(input("Enter first number :" ))
b = int(input("Enter second number :"))
print("Division of two numbers is :", a/b)
# Out:
# Enter first number :50
# Enter second number :5
# Division of two numbers is : 10.0

# %%
fname = input("Enter your first name : ")
lname = input("Enter your last name : ")
print(f"Hello.. {fname} {lname}, Kem Chho?")
# Out:
# Enter your first name : VP
# Enter your last name : Mishra
# Hello.. VP Mishra, Kem Chho?

# %%
num = int(input("Enter the number : "))
if (num%2==0):
  print("Number is Even")
else:
  print("Number id Odd")
# Out:
# Enter the number : 5
# Number id Odd
